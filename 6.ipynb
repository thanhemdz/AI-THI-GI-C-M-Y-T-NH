# %%
from PIL import Image
from imgtools import *
from IPython.display import display

# %%
# thu muc chua anh
path = 'C:/Users/ADMIN/Documents/Python AI/img/01/1.jpg'

# %%
img = load_image(path)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x332>

# %%
imgs = img.split()
for a in imgs:
    display(a)
newimg = Image.merge("RGB",imgs)
display(newimg)
# Out:
# <PIL.Image.Image image mode=L size=500x332>
# <PIL.Image.Image image mode=L size=500x332>
# <PIL.Image.Image image mode=L size=500x332>
# <PIL.Image.Image image mode=RGB size=500x332>

# %%
newimg = img.convert('L')

# %%
display(newimg)
# Out:
# <PIL.Image.Image image mode=L size=500x332>

# %%
# Out:
# 9
# tong  9
