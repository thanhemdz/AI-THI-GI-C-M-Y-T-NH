# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from PIL import Image

# %%
path = 'C:/Users/ADMIN/Documents/Python AI/img/01/1.jpg'
hinh = Image.open(path)
x = [100,150,300,450]
y = [250,100,150,230]
plt.imshow(hinh)
plt.plot(x,y,'r*:')
plt.show()

# %%
region = (75,50,180,160)
hinhMoi = hinh.crop(region)
display(hinhMoi)
# Out:
# <PIL.Image.Image image mode=RGB size=105x110>
