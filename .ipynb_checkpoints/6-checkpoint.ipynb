# %%
from PIL import Image
from imgtools import *
from IPython.display import display

# %%
# thu muc chua anh
path = 'C:/Users/ADMIN/Documents/Python AI/img/01/1.jpg'

# %%
img = load_image(path)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x332>

# %%
#cat anh cần : một khu vực(region)
region = (100,100,175,175)
newimg = img.crop(region)
display(newimg)
print(newimg.size)
# Out:
# <PIL.Image.Image image mode=RGB size=75x75>
# (75, 75)

# %%
viTriDan=(250,200)
img.paste(newimg,viTriDan)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x332>

# %%
img = img.transpose(Image.Transpose.ROTATE_90)
display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x332>
